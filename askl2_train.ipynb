# %% [markdown]
# # Projeto Final - Aprendizagem de Máquina 2025-2
#
# Neste notebook gravamos métricas, probabilidades e previsões em disco (`artifacts/askl2/<dataset>/`).
# Depois de executar esse notebook, execute o `model_comparison.ipynb` para gerar as visualizações comparativas dos modelos.

# %% [markdown]
# ## Instalando os pacotes
#
# Instalamos apenas o necessário para:
# - carregar datasets do OpenML;
# - pré-processar as bases com scikit-learn;
# - treinar o ASKL 2.0 (Auto-Sklearn 2.0).
#
# As dependências de visualização/análises agora residem em `model_comparison.ipynb`.

# %%
# %pip install auto-sklearn==0.15.0 \
    pandas==1.5.3 \
    openml==0.14.2 \
    numpy==1.24.4 \
    scikit-learn
# Out:
# Requirement already satisfied: auto-sklearn==0.15.0 in ./.venv/lib/python3.8/site-packages (0.15.0)
# Requirement already satisfied: pandas==1.5.3 in ./.venv/lib/python3.8/site-packages (1.5.3)
# Requirement already satisfied: openml==0.14.2 in ./.venv/lib/python3.8/site-packages (0.14.2)
# Requirement already satisfied: numpy==1.24.4 in ./.venv/lib/python3.8/site-packages (1.24.4)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.8/site-packages (0.24.2)
# Requirement already satisfied: ConfigSpace<0.5,>=0.4.21 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (0.4.21)
# Requirement already satisfied: smac<1.3,>=1.2 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.2)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (4.13.2)
# Requirement already satisfied: threadpoolctl in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (3.5.0)
# Requirement already satisfied: distro in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.9.0)
# Requirement already satisfied: scipy>=1.7.0 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.10.1)
# Requirement already satisfied: pynisher<0.7,>=0.6.3 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (0.6.4)
# Requirement already satisfied: dask>=2021.12 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (2023.5.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (56.0.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (6.0.3)
# Requirement already satisfied: liac-arff in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (2.5.0)
# Requirement already satisfied: pyrfr<0.9,>=0.8.1 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (0.8.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.4.2)
# Requirement already satisfied: distributed>=2012.12 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (2023.5.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas==1.5.3) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.venv/lib/python3.8/site-packages (from pandas==1.5.3) (2.9.0.post0)
# Requirement already satisfied: requests in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (2.32.4)
# Requirement already satisfied: minio in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (7.2.10)
# Requirement already satisfied: pyarrow in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (17.0.0)
# Requirement already satisfied: xmltodict in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (0.15.0)
# Requirement already satisfied: ConfigSpace<0.5,>=0.4.21 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (0.4.21)
# Requirement already satisfied: smac<1.3,>=1.2 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.2)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (4.13.2)
# Requirement already satisfied: threadpoolctl in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (3.5.0)
# Requirement already satisfied: distro in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.9.0)
# Requirement already satisfied: scipy>=1.7.0 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.10.1)
# Requirement already satisfied: pynisher<0.7,>=0.6.3 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (0.6.4)
# Requirement already satisfied: dask>=2021.12 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (2023.5.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (56.0.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (6.0.3)
# Requirement already satisfied: liac-arff in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (2.5.0)
# Requirement already satisfied: pyrfr<0.9,>=0.8.1 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (0.8.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (1.4.2)
# Requirement already satisfied: distributed>=2012.12 in ./.venv/lib/python3.8/site-packages (from auto-sklearn==0.15.0) (2023.5.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas==1.5.3) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.venv/lib/python3.8/site-packages (from pandas==1.5.3) (2.9.0.post0)
# Requirement already satisfied: requests in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (2.32.4)
# Requirement already satisfied: minio in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (7.2.10)
# Requirement already satisfied: pyarrow in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (17.0.0)
# Requirement already satisfied: xmltodict in ./.venv/lib/python3.8/site-packages (from openml==0.14.2) (0.15.0)
# Requirement already satisfied: pyparsing in ./.venv/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn==0.15.0) (3.1.4)
# Requirement already satisfied: cython in ./.venv/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn==0.15.0) (3.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (2025.3.0)
# Requirement already satisfied: partd>=1.2.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (1.4.1)
# Requirement already satisfied: click>=8.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (8.1.8)
# Requirement already satisfied: toolz>=0.10.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (25.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (8.5.0)
# Requirement already satisfied: urllib3>=1.24.3 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (2.2.3)
# Requirement already satisfied: zict>=2.2.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (3.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (2.4.0)
# Requirement already satisfied: tornado>=6.0.3 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (6.4.2)
# Requirement already satisfied: tblib>=1.6.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (3.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (1.1.1)
# Requirement already satisfied: locket>=1.0.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (1.0.0)
# Requirement already satisfied: psutil>=5.7.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (7.1.3)
# Requirement already satisfied: pyparsing in ./.venv/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn==0.15.0) (3.1.4)
# Requirement already satisfied: cython in ./.venv/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn==0.15.0) (3.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (2025.3.0)
# Requirement already satisfied: partd>=1.2.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (1.4.1)
# Requirement already satisfied: click>=8.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (8.1.8)
# Requirement already satisfied: toolz>=0.10.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (25.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in ./.venv/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn==0.15.0) (8.5.0)
# Requirement already satisfied: urllib3>=1.24.3 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (2.2.3)
# Requirement already satisfied: zict>=2.2.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (3.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (2.4.0)
# Requirement already satisfied: tornado>=6.0.3 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (6.4.2)
# Requirement already satisfied: tblib>=1.6.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (3.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (1.1.1)
# Requirement already satisfied: locket>=1.0.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (1.0.0)
# Requirement already satisfied: psutil>=5.7.0 in ./.venv/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn==0.15.0) (7.1.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.17.0)
# Requirement already satisfied: emcee>=3.0.0 in ./.venv/lib/python3.8/site-packages (from smac<1.3,>=1.2->auto-sklearn==0.15.0) (3.1.6)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.17.0)
# Requirement already satisfied: emcee>=3.0.0 in ./.venv/lib/python3.8/site-packages (from smac<1.3,>=1.2->auto-sklearn==0.15.0) (3.1.6)
# Requirement already satisfied: pycryptodome in ./.venv/lib/python3.8/site-packages (from minio->openml==0.14.2) (3.23.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.8/site-packages (from minio->openml==0.14.2) (2025.11.12)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.8/site-packages (from minio->openml==0.14.2) (25.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests->openml==0.14.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests->openml==0.14.2) (3.11)
# Requirement already satisfied: pycryptodome in ./.venv/lib/python3.8/site-packages (from minio->openml==0.14.2) (3.23.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.8/site-packages (from minio->openml==0.14.2) (2025.11.12)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.8/site-packages (from minio->openml==0.14.2) (25.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests->openml==0.14.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests->openml==0.14.2) (3.11)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.8/site-packages (from importlib-metadata>=4.13.0->dask>=2021.12->auto-sklearn==0.15.0) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.8/site-packages (from jinja2>=2.10.3->distributed>=2012.12->auto-sklearn==0.15.0) (2.1.5)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.8/site-packages (from argon2-cffi->minio->openml==0.14.2) (21.2.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.8/site-packages (from importlib-metadata>=4.13.0->dask>=2021.12->auto-sklearn==0.15.0) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.8/site-packages (from jinja2>=2.10.3->distributed>=2012.12->auto-sklearn==0.15.0) (2.1.5)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.8/site-packages (from argon2-cffi->minio->openml==0.14.2) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml==0.14.2) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml==0.14.2) (2.23)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml==0.14.2) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml==0.14.2) (2.23)
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Configurando o ambiente
# - define hiperparâmetros globais
# - fixa a semente para reprodutibilidade

# %%
SEARCH_ITERATIONS = 5
RANDOM_STATE = 42
CV_FOLDS = 5
N_JOBS = -1

import numpy as np
import warnings

warnings.filterwarnings('ignore')
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ## Obtenção e preparação dos dados
# Carrega os menores datasets de classificação do OpenML (CC-18) e armazena em
# memória para posterior divisão.

# %%
import openml

OPENML_CC18_ID = 99
NUM_DATASETS = 10

suite = openml.study.get_suite(suite_id=OPENML_CC18_ID)
datasets_df = openml.datasets.list_datasets(data_id=suite.data, output_format='dataframe')

datasets_df_sorted = datasets_df.sort_values(by='NumberOfInstances')
top_datasets = datasets_df_sorted.head(NUM_DATASETS)

datasets_memory = {}
for idx, row in top_datasets.iterrows():
    dataset_id = row['did']
    dataset_name = row['name']
    print(f"Fetching {dataset_name} (ID: {dataset_id}, Instances: {row['NumberOfInstances']})...")
    try:
        dataset = openml.datasets.get_dataset(dataset_id)
        X, y, _, _ = dataset.get_data(
            target=dataset.default_target_attribute,
            dataset_format='dataframe'
        )
        if y is not None:
            X['target'] = y
        datasets_memory[dataset_name] = X
    except Exception as exc:
        print(f"Failed to load {dataset_name}: {exc}")

print(f"Done! {len(datasets_memory)} datasets available in 'datasets_memory'.")
# Out:
# Fetching dresses-sales (ID: 23381, Instances: 500.0)...
# Fetching kc2 (ID: 1063, Instances: 522.0)...
# Fetching cylinder-bands (ID: 6332, Instances: 540.0)...
# Fetching climate-model-simulation-crashes (ID: 40994, Instances: 540.0)...
# Fetching wdbc (ID: 1510, Instances: 569.0)...
# Fetching ilpd (ID: 1480, Instances: 583.0)...
# Fetching balance-scale (ID: 11, Instances: 625.0)...
# Fetching credit-approval (ID: 29, Instances: 690.0)...
# Fetching breast-w (ID: 15, Instances: 699.0)...
# Fetching eucalyptus (ID: 188, Instances: 736.0)...
# Done! 10 datasets available in 'datasets_memory'.

# %% [markdown]
# ## Divisão dos dados em treino e teste
# Cada dataset é dividido em 70% treino e 30% teste usando a mesma seed.

# %%
from sklearn.model_selection import train_test_split

train_test_splits = {}
for dataset_name, df in datasets_memory.items():
    X = df.drop(columns=['target'])
    y = df['target']

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.30, random_state=RANDOM_STATE
    )

    train_test_splits[dataset_name] = {
        'X_train': X_train,
        'X_test': X_test,
        'y_train': y_train,
        'y_test': y_test,
        'train_size': len(X_train),
        'test_size': len(X_test)
    }

    print(f"{dataset_name}: treino={len(X_train)} | teste={len(X_test)}")

print(f"Total de {len(train_test_splits)} datasets divididos com sucesso!")
# Out:
# dresses-sales: treino=350 | teste=150
# kc2: treino=365 | teste=157
# cylinder-bands: treino=378 | teste=162
# climate-model-simulation-crashes: treino=378 | teste=162
# wdbc: treino=398 | teste=171
# ilpd: treino=408 | teste=175
# balance-scale: treino=437 | teste=188
# credit-approval: treino=483 | teste=207
# breast-w: treino=489 | teste=210
# eucalyptus: treino=515 | teste=221
# Total de 10 datasets divididos com sucesso!

# %% [markdown]
# ## Pré-processamento e artefatos compartilhados
# Utilitários responsáveis por codificar os dados e salvar artefatos do ASKL 2.0
# em `artifacts/askl2/<dataset_slug>/` (metadados + previsões).

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler, OrdinalEncoder
from artifact_utils import write_artifact_bundle, get_dataset_dir

ASKL_MODEL_KEY = 'askl2'


def artifact_exists(dataset_name: str) -> bool:
    dataset_dir = get_dataset_dir(ASKL_MODEL_KEY, dataset_name)
    return (
        dataset_dir.joinpath('metadata.json').exists()
        and dataset_dir.joinpath('predictions.npz').exists()
    )


def artifact_output_dir(dataset_name: str) -> str:
    return str(get_dataset_dir(ASKL_MODEL_KEY, dataset_name))


def preprocess_dataset(splits):
    X_train = splits['X_train']
    y_train = splits['y_train']
    X_test = splits['X_test']
    y_test = splits['y_test']

    le = LabelEncoder()
    y_train_encoded = le.fit_transform(y_train)
    y_test_encoded = le.transform(y_test)

    X_train_encoded = X_train.copy()
    X_test_encoded = X_test.copy()
    categorical_cols = X_train_encoded.select_dtypes(include=['object', 'category']).columns.tolist()

    if categorical_cols:
        oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
        X_train_encoded[categorical_cols] = oe.fit_transform(X_train_encoded[categorical_cols].astype(str))
        X_test_encoded[categorical_cols] = oe.transform(X_test_encoded[categorical_cols].astype(str))

    scaler = StandardScaler()
    numeric_cols = X_train_encoded.select_dtypes(include=[np.number]).columns
    X_train_scaled = X_train_encoded.copy()
    X_test_scaled = X_test_encoded.copy()
    if len(numeric_cols) > 0:
        X_train_scaled[numeric_cols] = scaler.fit_transform(X_train_encoded[numeric_cols])
        X_test_scaled[numeric_cols] = scaler.transform(X_test_encoded[numeric_cols])

    return {
        'X_train_encoded': X_train_encoded,
        'X_test_encoded': X_test_encoded,
        'X_train_scaled': X_train_scaled,
        'X_test_scaled': X_test_scaled,
        'y_train_encoded': y_train_encoded,
        'y_test_encoded': y_test_encoded,
        'y_train_original': y_train.reset_index(drop=True),
        'y_test_original': y_test.reset_index(drop=True),
        'label_encoder': le,
        'categorical_cols': categorical_cols,
        'numeric_cols': numeric_cols
    }

# %% [markdown]
# ## Treinamento dedicado com ASKL 2.0
# Roda o Auto-Sklearn 2.0 para cada dataset e persiste apenas artefatos
# (independentes do ambiente) que serão consumidos pelo notebook de comparação.

# %%
from autosklearn.experimental.askl2 import AutoSklearn2Classifier
from sklearn.metrics import accuracy_score
import time

processed_datasets = {}
total_datasets = len(train_test_splits)

ASKL_TIME_BUDGET = 300  # segundos
ASKL_PER_RUN_LIMIT = 120  # segundos por configuração
ASKL_MEMORY_LIMIT = 6144  # MB


def run_askl_training(processed_data):
    X_train = processed_data['X_train_scaled'].to_numpy()
    y_train = processed_data['y_train_encoded']
    X_test = processed_data['X_test_scaled'].to_numpy()
    y_test = processed_data['y_test_encoded']

    classifier = AutoSklearn2Classifier(
        time_left_for_this_task=ASKL_TIME_BUDGET,
        per_run_time_limit=ASKL_PER_RUN_LIMIT,
        memory_limit=ASKL_MEMORY_LIMIT,
        n_jobs=N_JOBS,
        seed=RANDOM_STATE,
    )

    start_time = time.time()
    classifier.fit(X_train, y_train)
    total_time = time.time() - start_time

    cv_score = np.nan
    try:
        cv_scores = classifier.cv_results_.get('mean_test_score')
        if cv_scores is not None:
            cv_score = float(np.nanmax(cv_scores))
    except Exception:
        pass

    y_prob = classifier.predict_proba(X_test)
    y_pred = classifier.predict(X_test)
    test_score = accuracy_score(y_test, y_pred)

    return {
        'y_prob': y_prob,
        'y_pred': y_pred,
        'cv_score': cv_score,
        'test_score': test_score,
        'runtime': total_time,
    }


askl_datasets_processed = 0
for dataset_idx, (dataset_name, splits) in enumerate(train_test_splits.items(), 1):
    print(f"{'='*80}")
    print(f"ASKL 2.0 | Dataset {dataset_idx}/{total_datasets}: {dataset_name}")
    print(f"{'='*80}")

    if artifact_exists(dataset_name):
        print("  ✓ Artefatos ASKL 2.0 já existem. Pulando...")
        continue

    processed_data = processed_datasets.get(dataset_name)
    if processed_data is None:
        processed_data = preprocess_dataset(splits)
        processed_datasets[dataset_name] = processed_data

    try:
        askl_result = run_askl_training(processed_data)
        write_artifact_bundle(
            model_key=ASKL_MODEL_KEY,
            dataset_name=dataset_name,
            y_true=processed_data['y_test_encoded'],
            y_pred=askl_result['y_pred'],
            y_prob=askl_result['y_prob'],
            class_labels=processed_data['label_encoder'].classes_.tolist(),
            metrics={
                'cv_accuracy': askl_result['cv_score'],
                'test_accuracy': askl_result['test_score'],
            },
            hyperparams={
                'time_left_for_this_task': ASKL_TIME_BUDGET,
                'per_run_time_limit': ASKL_PER_RUN_LIMIT,
                'memory_limit': ASKL_MEMORY_LIMIT,
                'seed': RANDOM_STATE,
                'n_jobs': N_JOBS,
            },
            runtime_seconds=askl_result['runtime'],
            extra_metadata={
                'train_samples': len(processed_data['X_train_encoded']),
                'test_samples': len(processed_data['X_test_encoded']),
            },
        )
        print(
            f"  ✓ ASKL 2.0 treinado! ACC teste = {askl_result['test_score']:.4f}\n"
            f"    → Artefatos salvos em {artifact_output_dir(dataset_name)}"
        )
        askl_datasets_processed += 1
    except Exception as exc:
        print(f"  ✗ Erro ao treinar ASKL 2.0: {str(exc)[:120]}")

print(f"{'='*80}")
print(f"ASKL 2.0 executado em {askl_datasets_processed} datasets.")
print(f"{'='*80}")
# Out:
# ================================================================================
# ASKL 2.0 | Dataset 1/10: dresses-sales
# ================================================================================
#   ✓ Artefatos ASKL 2.0 já existem. Pulando...
# ================================================================================
# ASKL 2.0 | Dataset 2/10: kc2
# ================================================================================
#   ✓ Artefatos ASKL 2.0 já existem. Pulando...
# ================================================================================
# ASKL 2.0 | Dataset 3/10: cylinder-bands
# ================================================================================
# [WARNING] [2025-11-21 01:44:41,613:Client-EnsembleBuilder] No runs were available to build an ensemble from
#   ✓ ASKL 2.0 treinado! ACC teste = 0.8086
#     → Artefatos salvos em artifacts/askl2/cylinder-bands
# ================================================================================
# ASKL 2.0 | Dataset 4/10: climate-model-simulation-crashes
# ================================================================================
#   ✓ ASKL 2.0 treinado! ACC teste = 0.9753
#     → Artefatos salvos em artifacts/askl2/climate-model-simulation-crashes
# ================================================================================
# ASKL 2.0 | Dataset 5/10: wdbc
# ================================================================================
#   ✓ ASKL 2.0 treinado! ACC teste = 0.9883
#     → Artefatos salvos em artifacts/askl2/wdbc
# ================================================================================
# ASKL 2.0 | Dataset 6/10: ilpd
# ================================================================================
# [WARNING] [2025-11-21 01:59:42,940:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:43,184:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:46,898:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:47,547:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:48,922:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:49,598:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:51,922:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:54,345:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:54,849:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:56,785:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:58,263:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 01:59:59,040:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:00,891:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:02,689:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:05,939:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:06,617:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:07,370:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:08,112:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:08,947:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:09,362:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:12,067:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:12,986:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:15,162:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:18,037:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:18,901:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:22,201:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:22,704:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:24,684:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:28,954:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:30,144:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:35,700:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:38,301:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:38,772:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:41,467:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:44,181:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:47,013:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:49,671:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:53,987:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:57,337:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:00:59,049:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:03,034:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:07,542:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:09,893:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:10,891:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:13,809:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:15,056:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:16,474:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:17,089:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:17,659:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:19,086:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:22,859:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-11-21 02:01:27,066:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
#   ✓ ASKL 2.0 treinado! ACC teste = 0.7371
#     → Artefatos salvos em artifacts/askl2/ilpd
# ================================================================================
# ASKL 2.0 | Dataset 7/10: balance-scale
# ================================================================================
#   ✓ ASKL 2.0 treinado! ACC teste = 0.9628
#     → Artefatos salvos em artifacts/askl2/balance-scale
# ================================================================================
# ASKL 2.0 | Dataset 8/10: credit-approval
# ================================================================================
#   ✓ ASKL 2.0 treinado! ACC teste = 0.8406
#     → Artefatos salvos em artifacts/askl2/credit-approval
# ================================================================================
# ASKL 2.0 | Dataset 9/10: breast-w
# ================================================================================
#   ✓ ASKL 2.0 treinado! ACC teste = 0.9714
#     → Artefatos salvos em artifacts/askl2/breast-w
# ================================================================================
# ASKL 2.0 | Dataset 10/10: eucalyptus
# ================================================================================
#   ✓ ASKL 2.0 treinado! ACC teste = 0.6290
#     → Artefatos salvos em artifacts/askl2/eucalyptus
# ================================================================================
# ASKL 2.0 executado em 8 datasets.
# ================================================================================

# %% [markdown]
# ## Próximos passos
# 1. Execute `SAINT.ipynb` para gerar `artifacts/saint/<dataset>/`.
# 2. Execute este notebook para gerar `artifacts/askl2/<dataset>/`.
# 3. Abra `model_comparison.ipynb` para carregar ambos os conjuntos e produzir as
#    tabelas, gráficos e testes estatísticos.

# %%
from pathlib import Path

artifact_root = Path('artifacts') / ASKL_MODEL_KEY
print(f"Artefatos ASKL 2.0: {artifact_root.resolve()}")
if not artifact_root.exists():
    print("Nenhum dataset processado ainda. Execute o treinamento acima.")
else:
    for dataset_dir in sorted(artifact_root.iterdir()):
        if dataset_dir.is_dir():
            print(f"  - {dataset_dir.name}")
# Out:
# Artefatos ASKL 2.0: /workspaces/AM-1/artifacts/askl2
#   - balance-scale
#   - breast-w
#   - climate-model-simulation-crashes
#   - credit-approval
#   - cylinder-bands
#   - dresses-sales
#   - eucalyptus
#   - ilpd
#   - kc2
#   - wdbc
